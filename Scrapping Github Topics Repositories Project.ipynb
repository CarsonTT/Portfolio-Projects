# %%
# OBJECTIVE

# Scrape topics from github 
# Grab 25 repositories from each topic which includes repository name, username, stars, and repository URL  
# Create a CSV file with all scrapped data

# %%
# Importing libraries


import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
# Defining what website to use


URL = 'https://github.com/topics'

page = requests.get(URL)

page_contents = page.text

doc = BeautifulSoup(page_contents,'html.parser')

# print(page_contents[:1000])

# %%
# Finding tags for topic names


topic_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'

topic_title_tags = doc.find_all('p',{'class': topic_class})

topic_title_tags[:5]
# Out:
# [<p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ajax</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Algorithm</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Amp</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Android</p>]

# %%
# Finding tags for descriptions


descr_class = 'f5 color-fg-muted mb-0 mt-1'

topic_descr_tags = doc.find_all('p',{'class': descr_class})

topic_descr_tags[:5]
# Out:
# [<p class="f5 color-fg-muted mb-0 mt-1">
#            3D modeling is the process of virtually developing the surface and structure of a 3D object.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ajax is a technique for creating interactive web applications.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Algorithms are self-contained sequences that carry out a variety of tasks.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Amp is a non-blocking concurrency library for PHP.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Android is an operating system built by Google designed for mobile devices.
#          </p>]

# %%
# finding link tags p1


topic_title_tag0 = topic_title_tags[0]

div_tag = topic_title_tag0.parent

div_tag
# Out:
# <a class="no-underline flex-1 d-flex flex-column" href="/topics/3d">
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>
# <p class="f5 color-fg-muted mb-0 mt-1">
#           3D modeling is the process of virtually developing the surface and structure of a 3D object.
#         </p>
# </a>

# %%
# finding link tags p2


link_class = 'no-underline flex-1 d-flex flex-column' #also the a tag

topic_link_tags = doc.find_all('a', {'class': link_class})

topic_link_tags[:5]
# Out:
# [<a class="no-underline flex-1 d-flex flex-column" href="/topics/3d">
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            3D modeling is the process of virtually developing the surface and structure of a 3D object.
#          </p>
#  </a>,
#  <a class="no-underline flex-1 d-flex flex-column" href="/topics/ajax">
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ajax</p>
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ajax is a technique for creating interactive web applications.
#          </p>
#  </a>,
#  <a class="no-underline flex-1 d-flex flex-column" href="/topics/algorithm">
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Algorithm</p>
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Algorithms are self-contained sequences that carry out a variety of tasks.
#          </p>
#  </a>,
#  <a class="no-underline flex-1 d-flex flex-column" href="/topics/amphp">
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Amp</p>
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Amp is a non-blocking concurrency library for PHP.
#          </p>
#  </a>,
#  <a class="no-underline flex-1 d-flex flex-column" href="/topics/android">
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Android</p>
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Android is an operating system built by Google designed for mobile devices.
#          </p>
#  </a>]

# %%
# Creating a topic titles list


topic_titles = []

for tag in topic_title_tags:
    topic_titles.append(tag.text)

topic_titles[:5]
# Out:
# ['3D', 'Ajax', 'Algorithm', 'Amp', 'Android']

# %%
# Creating a topic descriptions list


topic_descr = []

for tag in topic_descr_tags:
    topic_descr.append(tag.text.strip())

topic_descr[:5]
# Out:
# ['3D modeling is the process of virtually developing the surface and structure of a 3D object.',
#  'Ajax is a technique for creating interactive web applications.',
#  'Algorithms are self-contained sequences that carry out a variety of tasks.',
#  'Amp is a non-blocking concurrency library for PHP.',
#  'Android is an operating system built by Google designed for mobile devices.']

# %%
# Creating a topic links/URLs list


topic_urls = []

base_url = 'https://github.com'

for tag in topic_link_tags:
    topic_urls.append(base_url + tag['href'])
    
topic_urls[:5]
# Out:
# ['https://github.com/topics/3d',
#  'https://github.com/topics/ajax',
#  'https://github.com/topics/algorithm',
#  'https://github.com/topics/amphp',
#  'https://github.com/topics/android']

# %%
# Creating data frame 


topics_dict = {
    'title': topic_titles,
    'description': topic_descr,
    'url': topic_urls
}

topics_df = pd.DataFrame(topics_dict)

topics_df
# Out:
#                      title                                        description  \
# 0                       3D  3D modeling is the process of virtually develo...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source hardware and softwar...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10                    Atom  Atom is a open source text editor built with w...
# 11           Awesome Lists  An awesome list is a list of awesome things cu...
# 12     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 13                   Azure  Azure is a cloud computing service created by ...
# 14                   Babel  Babel is a compiler for writing next generatio...
# 15                    Bash  Bash is a shell and command language interpret...
# 16                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 17               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 18                     Bot  A bot is an application that runs automated ta...
# 19                       C  C is a general purpose programming language th...
# 20                  Chrome  Chrome is a web browser from the tech company ...
# 21        Chrome extension  Chrome extensions enable users to customize th...
# 22  Command line interface  A CLI, or command-line interface, is a console...
# 23                 Clojure  Clojure is a dynamic, general-purpose programm...
# 24            Code quality  Automate your code review with style, quality,...
# 25             Code review  Ensure your code meets quality standards and s...
# 26                Compiler  Compilers are software that translate higher-l...
# 27  Continuous integration  Automatically build and test your code as you ...
# 28                COVID-19  The coronavirus disease 2019 (COVID-19) is an ...
# 29                     C++  C++ is a general purpose and object-oriented p...
#
#                                                  url
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                    https://github.com/topics/atom
# 11                 https://github.com/topics/awesome
# 12                     https://github.com/topics/aws
# 13                   https://github.com/topics/azure
# 14                   https://github.com/topics/babel
# 15                    https://github.com/topics/bash
# 16                 https://github.com/topics/bitcoin
# 17               https://github.com/topics/bootstrap
# 18                     https://github.com/topics/bot
# 19                       https://github.com/topics/c
# 20                  https://github.com/topics/chrome
# 21        https://github.com/topics/chrome-extension
# 22                     https://github.com/topics/cli
# 23                 https://github.com/topics/clojure
# 24            https://github.com/topics/code-quality
# 25             https://github.com/topics/code-review
# 26                https://github.com/topics/compiler
# 27  https://github.com/topics/continuous-integration
# 28                https://github.com/topics/covid-19
# 29                     https://github.com/topics/cpp

# %%
# Creating a CSV file


topics_df.to_csv('topic.csv', index=None)
#                              ^ to get rid of row number

# %%
# Moving onto scraping the contents in each specific topic

# %%
# Defining what website/URL to use


topic_page_url = topic_urls[2]


topic_doc = BeautifulSoup(response.text, 'html.parser')

topic_page_url
# Out:
# 'https://github.com/topics/algorithm'

# %%
response = requests.get(topic_page_url)

response.status_code
# Out:
# 200

# %%
# Finding username and attached repository tags p1


repo_tags = topic_doc.find_all('h3',{'class': 'f3 color-fg-muted text-normal lh-condensed'})

a_tags = repo_tags[0].find_all('a')

a_tags
# Out:
# [<a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":3771963,"originating_url":"https://github.com/topics/algorithm","user_id":null}}' data-hydro-click-hmac="806006bf6ecca87f1d4103212d684b4f8f9d8f897c7349a1cd7e37852661db87" data-turbo="false" data-view-component="true" href="/jwasham">
#
#              jwasham
#
#
#  </a>,
#  <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":60493101,"originating_url":"https://github.com/topics/algorithm","user_id":null}}' data-hydro-click-hmac="00d35a03113917ed4a7133838f34531a079c7e92d024d3355218293bb04b5d81" data-turbo="false" data-view-component="true" href="/jwasham/coding-interview-university">
#
#              coding-interview-university
#
#
#  </a>]

# %%
# Finding (username) and attached repository tags p2


a_tags[0].text.strip()
# Out:
# 'jwasham'

# %%
# Finding username and attached (repository) tags p3


a_tags[1].text.strip()
# Out:
# 'coding-interview-university'

# %%
# Creating URL for attached repository


repo_url = base_url + a_tags[1]['href']

repo_url
# Out:
# 'https://github.com/jwasham/coding-interview-university'

# %%
# Finding star tags

star_class = 'repo-stars-counter-star'

star_tags = topic_doc.find_all(id= star_class)

# star_tags[:5]

star_tags[0].text
# Out:
# '219k'

# %%
# Changing star_tags from text to int


def parse_star_count(stars_str):
    if stars_str[-1] == 'k':
        return int(float(stars_str[:-1]) * 1000)
    return int(stars_str)


parse_star_count(star_tags[0].text)
# Out:
# 219000

# %%
# Creating function to return all required info about a repository


def get_repo_info(repo_tags, star_tags):
    a_tags = repo_tags.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tags.text)
    return username, repo_name, stars, repo_url

get_repo_info(repo_tags[0], star_tags[0])
# Out:
# ('jwasham',
#  'coding-interview-university',
#  219000,
#  'https://github.com/jwasham/coding-interview-university')

# %%
# Create data frame p1


topic_repos_dict = {
    'username':[],
    'repo_name':[],
    'stars': [],
    'repo_url': []
}

for x in range(len(repo_tags)):
    repo_info = get_repo_info(repo_tags[x], star_tags[x])
    topic_repos_dict['username'].append(repo_info[0])
    topic_repos_dict['repo_name'].append(repo_info[1])
    topic_repos_dict['stars'].append(repo_info[2])
    topic_repos_dict['repo_url'].append(repo_info[3])

# %%
# Create data frame p2



topic_repos_df = pd.DataFrame(topic_repos_dict)

topic_repos_df
# Out:
#                 username                        repo_name   stars  \
# 0                jwasham      coding-interview-university  219000
# 1                CyC2018                         CS-Notes  150000
# 2               trekhleb            javascript-algorithms  140000
# 3          TheAlgorithms                           Python  136000
# 4               yangshun          tech-interview-handbook   69600
# 5                 kdn251                       interviews   57100
# 6           azl397985856                         leetcode   47800
# 7          TheAlgorithms                             Java   45900
# 8   algorithm-visualizer             algorithm-visualizer   36800
# 9           crossoverJie                         JCSprout   26700
# 10       youngyangyang04                  leetcode-master   26300
# 11           donnemartin    interactive-coding-challenges   25400
# 12              halfrost                      LeetCode-Go   24700
# 13                huihut                        interview   24000
# 14                  keon                       algorithms   20700
# 15         TheAlgorithms                       JavaScript   19700
# 16              trekhleb        homemade-machine-learning   19300
# 17         TheAlgorithms                      C-Plus-Plus   19300
# 18                 mxgmn             WaveFunctionCollapse   18400
# 19          AtsushiSakai                   PythonRobotics   15200
# 20           greyireland                algorithm-pattern   13400
# 21             OpenGenus                           cosmos   13000
# 22          williamfiset                       Algorithms   12500
# 23              halfrost                   Halfrost-Field   11000
# 24              apachecn                 apachecn-algo-zh   10600
# 25               lnishan  awesome-competitive-programming    9700
# 26                Blankj            awesome-java-leetcode    8400
# 27         jeffgerickson                       algorithms    7500
# 28   LeetCode-OpenSource                  vscode-leetcode    7300
# 29               mgechev            javascript-algorithms    7200
#
#                                              repo_url
# 0   https://github.com/jwasham/coding-interview-un...
# 1                 https://github.com/CyC2018/CS-Notes
# 2   https://github.com/trekhleb/javascript-algorithms
# 3             https://github.com/TheAlgorithms/Python
# 4   https://github.com/yangshun/tech-interview-han...
# 5                https://github.com/kdn251/interviews
# 6            https://github.com/azl397985856/leetcode
# 7               https://github.com/TheAlgorithms/Java
# 8   https://github.com/algorithm-visualizer/algori...
# 9            https://github.com/crossoverJie/JCSprout
# 10  https://github.com/youngyangyang04/leetcode-ma...
# 11  https://github.com/donnemartin/interactive-cod...
# 12            https://github.com/halfrost/LeetCode-Go
# 13                https://github.com/huihut/interview
# 14                 https://github.com/keon/algorithms
# 15        https://github.com/TheAlgorithms/JavaScript
# 16  https://github.com/trekhleb/homemade-machine-l...
# 17       https://github.com/TheAlgorithms/C-Plus-Plus
# 18      https://github.com/mxgmn/WaveFunctionCollapse
# 19     https://github.com/AtsushiSakai/PythonRobotics
# 20   https://github.com/greyireland/algorithm-pattern
# 21                https://github.com/OpenGenus/cosmos
# 22         https://github.com/williamfiset/Algorithms
# 23         https://github.com/halfrost/Halfrost-Field
# 24       https://github.com/apachecn/apachecn-algo-zh
# 25  https://github.com/lnishan/awesome-competitive...
# 26    https://github.com/Blankj/awesome-java-leetcode
# 27        https://github.com/jeffgerickson/algorithms
# 28  https://github.com/LeetCode-OpenSource/vscode-...
# 29   https://github.com/mgechev/javascript-algorithms

# %%
# Creating function to grab topic repository


def get_topic_repos1(topic_urls):
    
    # Download page
    response = requests.get(topic_urls)
    
    # Check successfull response
    if response.status_code !=200:
        raise Exception('failed to load page {}'.format(topic_url))
        
    # Parse using BeautifulSoup    
    topic_doc = BeautifulSoup(response.content, 'html.parser')
    
    # Get repo tags(or h3 tags) containing repo title, repo URL and username 
    repo_tags = topic_doc.find_all('h3',{'class': 'f3 color-fg-muted text-normal lh-condensed'})
    
    # Get star tags
    star_tags = topic_doc.find_all(id= star_class)
    
    # topic repository dictionary
    topic_repos_dict = {
        'username':[],
        'repo_name':[],
        'stars': [],
        'repo_url': []
    }
    
    # Get repo info
    for x in range(len(repo_tags)):
        repo_info = get_repo_info(repo_tags[x], star_tags[x])
        topic_repos_dict['username'].append(repo_info[0])
        topic_repos_dict['repo_name'].append(repo_info[1])
        topic_repos_dict['stars'].append(repo_info[2])
        topic_repos_dict['repo_url'].append(repo_info[3])
    
    return pd.DataFrame(topic_repos_dict)

# %%
# Testing Fuction 


get_topic_repos1(topic_urls[1])
# Out:
#                     username  \
# 0                  metafizzy
# 1                   ljianshu
# 2                  developit
# 3                jquery-form
# 4                 olifolkerd
# 5                  Studio-42
# 6                        ded
# 7                       dwyl
# 8                    elbywan
# 9                   LeaVerou
# 10                  noelboss
# 11                    wendux
# 12                  yisainan
# 13                  craftpip
# 14               ptaoussanis
# 15                 joaomilho
# 16                     nette
# 17                u014427391
# 18                 loadingio
# 19                      MoOx
# 20    codingforentrepreneurs
# 21                   danielm
# 22                       k8w
# 23              renderedtext
# 24                     swlib
# 25                proyecto26
# 26  opensource-socialnetwork
# 27                 webcreate
# 28                   rapidjs
# 29         csxiaoyaojianxian
#
#                                             repo_name  stars  \
# 0                                     infinite-scroll   7100
# 1                                                Blog   7100
# 2                                             unfetch   5300
# 3                                                form   5100
# 4                                           tabulator   4600
# 5                                            elFinder   4300
# 6                                             reqwest   2900
# 7   learn-to-send-email-via-google-script-html-no-...   2800
# 8                                              wretch   2400
# 9                                               bliss   2400
# 10                                       featherlight   2100
# 11                                          ajax-hook   2000
# 12                                      web-interview   2000
# 13                                     jquery-confirm   1800
# 14                                              sente   1600
# 15                                         Enterprise   1500
# 16                                              tracy   1500
# 17                                        jeeplatform   1400
# 18                                        css-spinner   1300
# 19                                               pjax   1300
# 20                                          eCommerce   1200
# 21                                           uploader   1100
# 22                                              tsrpc   1100
# 23                                       render_async   1000
# 24                                              saber    952
# 25                                         RestClient    917
# 26                           opensource-socialnetwork    856
# 27                               infinite-ajax-scroll    856
# 28                                           rapid.js    708
# 29                                    JavaScriptStudy    607
#
#                                              repo_url
# 0        https://github.com/metafizzy/infinite-scroll
# 1                    https://github.com/ljianshu/Blog
# 2                https://github.com/developit/unfetch
# 3                 https://github.com/jquery-form/form
# 4             https://github.com/olifolkerd/tabulator
# 5               https://github.com/Studio-42/elFinder
# 6                      https://github.com/ded/reqwest
# 7   https://github.com/dwyl/learn-to-send-email-vi...
# 8                   https://github.com/elbywan/wretch
# 9                   https://github.com/LeaVerou/bliss
# 10           https://github.com/noelboss/featherlight
# 11                https://github.com/wendux/ajax-hook
# 12          https://github.com/yisainan/web-interview
# 13         https://github.com/craftpip/jquery-confirm
# 14               https://github.com/ptaoussanis/sente
# 15            https://github.com/joaomilho/Enterprise
# 16                     https://github.com/nette/tracy
# 17          https://github.com/u014427391/jeeplatform
# 18           https://github.com/loadingio/css-spinner
# 19                       https://github.com/MoOx/pjax
# 20  https://github.com/codingforentrepreneurs/eCom...
# 21                https://github.com/danielm/uploader
# 22                       https://github.com/k8w/tsrpc
# 23       https://github.com/renderedtext/render_async
# 24                     https://github.com/swlib/saber
# 25           https://github.com/proyecto26/RestClient
# 26  https://github.com/opensource-socialnetwork/op...
# 27  https://github.com/webcreate/infinite-ajax-scroll
# 28                https://github.com/rapidjs/rapid.js
# 29  https://github.com/csxiaoyaojianxian/JavaScrip...

# %%
# splitting function into multiple functions 


def get_topic_page(topic_urls):
    
    # Download page
    response = requests.get(topic_urls)
    
    # Check successfull response
    if response.status_code !=200:
        raise Exception('failed to load page {}'.format(topic_urls))
        
    # Parse using BeautifulSoup    
    topic_doc = BeautifulSoup(response.content, 'html.parser')
    
    return topic_doc


def get_repo_info(repo_tags, star_tags):
    a_tags = repo_tags.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tags.text)
    
    # returns all the required info about a repository
    return username, repo_name, stars, repo_url


def get_topic_repos(topic_doc):
    
    # Get repo tags(or h3 tags) containing repo title, repo URL and username 
    repo_tags = topic_doc.find_all('h3',{'class': 'f3 color-fg-muted text-normal lh-condensed'})
    
    # Get star tags
    star_tags = topic_doc.find_all(id= star_class)
    
    # topic repository dictionary
    topic_repos_dict = {
        'username':[],
        'repo_name':[],
        'stars': [],
        'repo_url': []
    }
    
    # Get repo info
    for x in range(len(repo_tags)):
        repo_info = get_repo_info(repo_tags[x], star_tags[x])
        topic_repos_dict['username'].append(repo_info[0])
        topic_repos_dict['repo_name'].append(repo_info[1])
        topic_repos_dict['stars'].append(repo_info[2])
        topic_repos_dict['repo_url'].append(repo_info[3])
    
    return pd.DataFrame(topic_repos_dict)

# %%
# Testing multiple functions


url0 = topic_urls[0]

topic0_doc = get_topic_page(url0)

topic0_repos = get_topic_repos(topic0_doc)

topic0_repos
# Out:
#             username                      repo_name  stars  \
# 0             mrdoob                       three.js  81700
# 1             libgdx                         libgdx  20000
# 2             pmndrs              react-three-fiber  17800
# 3          BabylonJS                     Babylon.js  16700
# 4           aframevr                         aframe  14100
# 5              ssloy                   tinyrenderer  13600
# 6            lettier  3d-game-shaders-for-beginners  12800
# 7            FreeCAD                        FreeCAD  11200
# 8          metafizzy                           zdog   9100
# 9           CesiumGS                         cesium   8600
# 10       timzhang642            3D-Machine-Learning   7900
# 11      a1studmuffin             SpaceshipGenerator   7100
# 12           isl-org                         Open3D   6700
# 13           blender                        blender   5500
# 14           domlysz                     BlenderGIS   5200
# 15          spritejs                       spritejs   4800
# 16          openscad                       openscad   4800
# 17           jagenjo                 webglstudio.js   4600
# 18  tensorspace-team                    tensorspace   4600
# 19           YadiraF                          PRNet   4600
# 20      AaronJackson                            vrn   4400
# 21            google                   model-viewer   4300
# 22             ssloy                  tinyraytracer   4200
# 23             mosra                         magnum   4000
# 24       FyroxEngine                          Fyrox   3600
# 25   gfxfundamentals             webgl-fundamentals   3600
# 26           tengbao                          vanta   3500
# 27         cleardusk                          3DDFA   3200
# 28         jasonlong        isometric-contributions   3200
# 29    cnr-isti-vclab                        meshlab   2900
#
#                                              repo_url
# 0                  https://github.com/mrdoob/three.js
# 1                    https://github.com/libgdx/libgdx
# 2         https://github.com/pmndrs/react-three-fiber
# 3             https://github.com/BabylonJS/Babylon.js
# 4                  https://github.com/aframevr/aframe
# 5               https://github.com/ssloy/tinyrenderer
# 6   https://github.com/lettier/3d-game-shaders-for...
# 7                  https://github.com/FreeCAD/FreeCAD
# 8                   https://github.com/metafizzy/zdog
# 9                  https://github.com/CesiumGS/cesium
# 10  https://github.com/timzhang642/3D-Machine-Lear...
# 11  https://github.com/a1studmuffin/SpaceshipGener...
# 12                  https://github.com/isl-org/Open3D
# 13                 https://github.com/blender/blender
# 14              https://github.com/domlysz/BlenderGIS
# 15               https://github.com/spritejs/spritejs
# 16               https://github.com/openscad/openscad
# 17          https://github.com/jagenjo/webglstudio.js
# 18    https://github.com/tensorspace-team/tensorspace
# 19                   https://github.com/YadiraF/PRNet
# 20                https://github.com/AaronJackson/vrn
# 21             https://github.com/google/model-viewer
# 22             https://github.com/ssloy/tinyraytracer
# 23                    https://github.com/mosra/magnum
# 24               https://github.com/FyroxEngine/Fyrox
# 25  https://github.com/gfxfundamentals/webgl-funda...
# 26                   https://github.com/tengbao/vanta
# 27                 https://github.com/cleardusk/3DDFA
# 28  https://github.com/jasonlong/isometric-contrib...
# 29          https://github.com/cnr-isti-vclab/meshlab

# %%
# Creating a function to scrape topics


def scrape_topics1():
    topics_url = 'https://github.com/topics'
    requests.get(topics_url)
    if response.status_code !=200:
        raise Exception('failed to load page {}'.format(topic_urls))
        
        
    topic_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'
    topic_title_tags = doc.find_all('p',{'class': topic_class})
    
    
    descr_class = 'f5 color-fg-muted mb-0 mt-1'
    topic_descr_tags = doc.find_all('p',{'class': descr_class})
    
    
    link_class = 'no-underline flex-1 d-flex flex-column' 
    topic_link_tags = doc.find_all('a', {'class': link_class})
   

    topic_titles = []

    for tag in topic_title_tags:
        topic_titles.append(tag.text)
    
    
    topic_descr = []

    for tag in topic_descr_tags:
        topic_descr.append(tag.text.strip())

    
    topic_urls = []

    base_url = 'https://github.com'

    for tag in topic_link_tags:
        topic_urls.append(base_url + tag['href'])
     
    
    topics_dict = {
        'title':get_topic_titles(doc),
        'description': get_topic_descrs(doc),
        'url': get_topic_urls(doc)
    }
    return pd.DataFrame(topics_dict)     


# Testing Function


scrape_topics1()
# Out:
#                      title                                        description  \
# 0                       3D  3D modeling is the process of virtually develo...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source hardware and softwar...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10                    Atom  Atom is a open source text editor built with w...
# 11           Awesome Lists  An awesome list is a list of awesome things cu...
# 12     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 13                   Azure  Azure is a cloud computing service created by ...
# 14                   Babel  Babel is a compiler for writing next generatio...
# 15                    Bash  Bash is a shell and command language interpret...
# 16                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 17               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 18                     Bot  A bot is an application that runs automated ta...
# 19                       C  C is a general purpose programming language th...
# 20                  Chrome  Chrome is a web browser from the tech company ...
# 21        Chrome extension  Chrome extensions enable users to customize th...
# 22  Command line interface  A CLI, or command-line interface, is a console...
# 23                 Clojure  Clojure is a dynamic, general-purpose programm...
# 24            Code quality  Automate your code review with style, quality,...
# 25             Code review  Ensure your code meets quality standards and s...
# 26                Compiler  Compilers are software that translate higher-l...
# 27  Continuous integration  Automatically build and test your code as you ...
# 28                COVID-19  The coronavirus disease 2019 (COVID-19) is an ...
# 29                     C++  C++ is a general purpose and object-oriented p...
#
#                                                  url
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                    https://github.com/topics/atom
# 11                 https://github.com/topics/awesome
# 12                     https://github.com/topics/aws
# 13                   https://github.com/topics/azure
# 14                   https://github.com/topics/babel
# 15                    https://github.com/topics/bash
# 16                 https://github.com/topics/bitcoin
# 17               https://github.com/topics/bootstrap
# 18                     https://github.com/topics/bot
# 19                       https://github.com/topics/c
# 20                  https://github.com/topics/chrome
# 21        https://github.com/topics/chrome-extension
# 22                     https://github.com/topics/cli
# 23                 https://github.com/topics/clojure
# 24            https://github.com/topics/code-quality
# 25             https://github.com/topics/code-review
# 26                https://github.com/topics/compiler
# 27  https://github.com/topics/continuous-integration
# 28                https://github.com/topics/covid-19
# 29                     https://github.com/topics/cpp

# %%
# Splitting scrape_topic into mutiple functions


def get_topic_titles(doc):
    topic_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'
    topic_title_tags = doc.find_all('p',{'class': topic_class})
    topic_titles = []
    for tag in topic_title_tags:
        topic_titles.append(tag.text)
    return topic_titles


def get_topic_descrs(doc):
    descr_class = 'f5 color-fg-muted mb-0 mt-1'
    topic_descr_tags = doc.find_all('p',{'class': descr_class})
    topic_descr = []
    for tag in topic_descr_tags:
        topic_descr.append(tag.text.strip())
    return topic_descr


def get_topic_urls(doc):
    link_class = 'no-underline flex-1 d-flex flex-column' 
    topic_link_tags = doc.find_all('a', {'class': link_class})
    topic_urls = []
    base_url = 'https://github.com'
    for tag in topic_link_tags:
        topic_urls.append(base_url + tag['href'])
    return topic_urls

# %%
#create a function to scrape top topics


def scrape_topics():
    topics_url = 'https://github.com/topics'
    requests.get(topics_url)
    if response.status_code !=200:
        raise Exception('failed to load page {}'.format(topic_urls))
    topics_dict = {
        'title':get_topic_titles(doc),
        'description': get_topic_descrs(doc),
        'url': get_topic_urls(doc)
    }
    return pd.DataFrame(topics_dict)


# Testing function
scrape_topics()
# Out:
#                      title                                        description  \
# 0                       3D  3D modeling is the process of virtually develo...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source hardware and softwar...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10                    Atom  Atom is a open source text editor built with w...
# 11           Awesome Lists  An awesome list is a list of awesome things cu...
# 12     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 13                   Azure  Azure is a cloud computing service created by ...
# 14                   Babel  Babel is a compiler for writing next generatio...
# 15                    Bash  Bash is a shell and command language interpret...
# 16                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 17               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 18                     Bot  A bot is an application that runs automated ta...
# 19                       C  C is a general purpose programming language th...
# 20                  Chrome  Chrome is a web browser from the tech company ...
# 21        Chrome extension  Chrome extensions enable users to customize th...
# 22  Command line interface  A CLI, or command-line interface, is a console...
# 23                 Clojure  Clojure is a dynamic, general-purpose programm...
# 24            Code quality  Automate your code review with style, quality,...
# 25             Code review  Ensure your code meets quality standards and s...
# 26                Compiler  Compilers are software that translate higher-l...
# 27  Continuous integration  Automatically build and test your code as you ...
# 28                COVID-19  The coronavirus disease 2019 (COVID-19) is an ...
# 29                     C++  C++ is a general purpose and object-oriented p...
#
#                                                  url
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                    https://github.com/topics/atom
# 11                 https://github.com/topics/awesome
# 12                     https://github.com/topics/aws
# 13                   https://github.com/topics/azure
# 14                   https://github.com/topics/babel
# 15                    https://github.com/topics/bash
# 16                 https://github.com/topics/bitcoin
# 17               https://github.com/topics/bootstrap
# 18                     https://github.com/topics/bot
# 19                       https://github.com/topics/c
# 20                  https://github.com/topics/chrome
# 21        https://github.com/topics/chrome-extension
# 22                     https://github.com/topics/cli
# 23                 https://github.com/topics/clojure
# 24            https://github.com/topics/code-quality
# 25             https://github.com/topics/code-review
# 26                https://github.com/topics/compiler
# 27  https://github.com/topics/continuous-integration
# 28                https://github.com/topics/covid-19
# 29                     https://github.com/topics/cpp

# %%
# Creating a function to scrape a topic


def scrape_topic(topic_url, topic_name):
        fname = topic_name + '.csv'
        if os.path.exists(fname):
            print('The file {} already exists. Skipping...'.format(fname))
            return
        topic_df = get_topic_repos(get_topic_page(topic_url))
        topic_df.to_csv(topic_name +'.csv', index=None)
    
    
# Testing function

# %%
# Creating function to scrape topic repository


def scrape_topics_repos():
    print('Scraping list of topics')
    topics_df = scrape_topics()
    
    for index, row in topics_df.iterrows():
        print('Scraping top repositories for "{}"'.format(row['title']))
        scrape_topic(row['url'], row['title'])

        
# test

scrape_topics_repos()
# Out:
# Scraping list of topics
# Scraping top repositories for "3D"
# The file 3D.csv already exists. Skipping...
# Scraping top repositories for "Ajax"
# The file Ajax.csv already exists. Skipping...
# Scraping top repositories for "Algorithm"
# The file Algorithm.csv already exists. Skipping...
# Scraping top repositories for "Amp"
# The file Amp.csv already exists. Skipping...
# Scraping top repositories for "Android"
# The file Android.csv already exists. Skipping...
# Scraping top repositories for "Angular"
# The file Angular.csv already exists. Skipping...
# Scraping top repositories for "Ansible"
# The file Ansible.csv already exists. Skipping...
# Scraping top repositories for "API"
# The file API.csv already exists. Skipping...
# Scraping top repositories for "Arduino"
# The file Arduino.csv already exists. Skipping...
# Scraping top repositories for "ASP.NET"
# The file ASP.NET.csv already exists. Skipping...
# Scraping top repositories for "Atom"
# The file Atom.csv already exists. Skipping...
# Scraping top repositories for "Awesome Lists"
# The file Awesome Lists.csv already exists. Skipping...
# Scraping top repositories for "Amazon Web Services"
# The file Amazon Web Services.csv already exists. Skipping...
# Scraping top repositories for "Azure"
# The file Azure.csv already exists. Skipping...
# Scraping top repositories for "Babel"
# The file Babel.csv already exists. Skipping...
# Scraping top repositories for "Bash"
# The file Bash.csv already exists. Skipping...
# Scraping top repositories for "Bitcoin"
# The file Bitcoin.csv already exists. Skipping...
# Scraping top repositories for "Bootstrap"
# The file Bootstrap.csv already exists. Skipping...
# Scraping top repositories for "Bot"
# The file Bot.csv already exists. Skipping...
# Scraping top repositories for "C"
# The file C.csv already exists. Skipping...
# Scraping top repositories for "Chrome"
# The file Chrome.csv already exists. Skipping...
# Scraping top repositories for "Chrome extension"
# Scraping top repositories for "Command line interface"
# Scraping top repositories for "Clojure"
# Scraping top repositories for "Code quality"
# Scraping top repositories for "Code review"
# Scraping top repositories for "Compiler"
# Scraping top repositories for "Continuous integration"
# Scraping top repositories for "COVID-19"
# Scraping top repositories for "C++"
